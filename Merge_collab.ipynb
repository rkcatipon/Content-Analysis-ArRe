# %%
from google.colab import drive
drive.mount('/content/drive/',force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
from zipfile import ZipFile 
import os 
import pandas
import time
  
def get_all_file_paths(directory): 
  
    # initializing empty file paths list 
    file_paths = [] 
  
    # crawling through directory and subdirectories 
    for root, directories, files in os.walk(directory): 
        for filename in files: 
           #get only news_df pkl files
            if ('news_df') in filename and ('.pkl') in filename:
               # join the two strings in order to form the full filepath. 
                filepath = os.path.join(root, filename) 
                file_paths.append(filepath) 
  
    # returning all file paths 
    return file_paths         
  

# path to folder which has pkl files 
directory = '/content/drive/My Drive/SOCI 40133 - Final Project/Data'

# calling function to get all file paths in the directory 
file_paths = get_all_file_paths(directory) 

# printing the list of all files to be zipped 
print('Following' ,len(file_paths),'files will be merged')
print(file_paths)
dfs = []
t0=time.time()
for file_name in file_paths: 
    dfs.append(pandas.read_pickle(file_name))
t1=time.time()
print('List of dfs created in ', t1-t0)
t2=time.time()
full_news_df=pandas.concat(dfs, verify_integrity=True)
print('All DFs sucessfully concatanated in ',time.time()-t2)
#print('Df concat successful!')
# Out:
# Following 9 files will be merged
# ['/content/drive/My Drive/SOCI 40133 - Final Project/Data/2016-10_news_df.pkl', '/content/drive/My Drive/SOCI 40133 - Final Project/Data/2017-09_news_df.pkl', '/content/drive/My Drive/SOCI 40133 - Final Project/Data/2017-08_news_df.pkl', '/content/drive/My Drive/SOCI 40133 - Final Project/Data/2017-06_news_df.pkl', '/content/drive/My Drive/SOCI 40133 - Final Project/Data/2016-12_news_df.pkl', '/content/drive/My Drive/SOCI 40133 - Final Project/Data/2017-03_news_df.pkl', '/content/drive/My Drive/SOCI 40133 - Final Project/Data/2017-10_news_df.pkl', '/content/drive/My Drive/SOCI 40133 - Final Project/Data/2017-05_news_df.pkl', '/content/drive/My Drive/SOCI 40133 - Final Project/Data/2017-04_news_df.pkl']
# List of dfs created in  4.396174192428589
# All DFs sucessfully concatanated in  0.4773375988006592

# %%
full_news_df.head()

# %%
full_news_df.shape

# %%
full_news_df.to_pickle('/content/drive/My Drive/SOCI 40133 - Final Project/Data/full_news_df.pkl')
print('Saved file')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
drive.flush_and_unmount()
print('All changes made in this colab session should now be visible in Drive.')
